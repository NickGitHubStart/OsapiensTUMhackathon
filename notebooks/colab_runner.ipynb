# %% [markdown]
# # Colab Runner
#
# This notebook clones the repo, installs dependencies, downloads the dataset, and runs the XGBoost baseline.
#
# Notes:
# - Set `REPO_URL` to your fork before running cell 2.
# - Default data location is `/content/data`.
# - If you store data on Drive, update the `DATA_DIR` cell accordingly.

# %%
# Clone repo (set this to your fork if needed)
REPO_URL = "<REPO_URL>"
REPO_DIR = "tum_ai_hack"

if REPO_URL != "<REPO_URL>":
    # !git clone {REPO_URL} {REPO_DIR}
    # %cd {REPO_DIR}
else:
    print("Set REPO_URL to your repo before running this cell.")

# %%
# Install dependencies (run after cloning)
# !python -m pip install -U pip
# !python -m pip install -r ONI-makeathon-challenge-2026-main/requirements.txt

# %%
# Set where to store data
DATA_DIR = "/content/data"

# %%
# Download dataset from the public S3 bucket
# !python -m src.download_data --local-dir {DATA_DIR}

# %%
# Run the XGBoost baseline
# !python -m src.train_baseline --data-dir {DATA_DIR}/makeathon-challenge
